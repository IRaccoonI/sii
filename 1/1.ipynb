# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_name = '2015.csv'
df = pd.read_csv(file_name)
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
my_df = pd.DataFrame({
    'id': list(range(3)),
    'name': ['Bob', 'Joe', 'Mike'],
    'age': [22, 32, 16],
})
my_df
# Out:
#    id  name  age
# 0   0   Bob   22
# 1   1   Joe   32
# 2   2  Mike   16

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
from enum import Enum


df.rename(columns={
    col_name: col_name.replace(' ', '_').replace('(', '_').replace(')', '').lower() for col_name in df.columns
}, inplace=True)

class DfCols:
    country = 'country' 
    region = 'region' 
    happiness_rank = 'happiness_rank' 
    happiness_score = 'happiness_score'
    standard_error = 'standard_error' 
    economy__gdp_per_capita = 'economy__gdp_per_capita' 
    family = 'family'
    health__life_expectancy = 'health__life_expectancy' 
    freedom = 'freedom' 
    trust__government_corruption = 'trust__government_corruption'
    generosity = 'generosity' 
    dystopia_residual = 'dystopia_residual'
    sum = 'sum'
    happiness_rounded = 'happiness_rounded'

df[DfCols.sum] = 0
df[DfCols.happiness_rounded] = 0

df.columns
# Out:
# Index(['country', 'region', 'happiness_rank', 'happiness_score',
#        'standard_error', 'economy__gdp_per_capita', 'family',
#        'health__life_expectancy', 'freedom', 'trust__government_corruption',
#        'generosity', 'dystopia_residual', 'sum', 'happiness_rounded'],
#       dtype='object')

# %%
df.describe()
# Out:
#        happiness_rank  happiness_score  standard_error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        economy__gdp_per_capita      family  health__life_expectancy  \
# count               158.000000  158.000000               158.000000
# mean                  0.846137    0.991046                 0.630259
# std                   0.403121    0.272369                 0.247078
# min                   0.000000    0.000000                 0.000000
# 25%                   0.545808    0.856823                 0.439185
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       158 non-null    object
#  1   region                        158 non-null    object
#  2   happiness_rank                158 non-null    int64
#  3   happiness_score               158 non-null    float64
#  4   standard_error                158 non-null    float64
#  5   economy__gdp_per_capita       158 non-null    float64
#  6   family                        158 non-null    float64
#  7   health__life_expectancy       158 non-null    float64
#  8   freedom                       158 non-null    float64
#  9   trust__government_corruption  158 non-null    float64
#  10  generosity                    158 non-null    float64
#  11  dystopia_residual             158 non-null    float64
# ...

# %%
df_slice = df[[df.columns[i] for i in range(2)]]
df_slice
# Out:
#          country                           region
# 0    Switzerland                   Western Europe
# 1        Iceland                   Western Europe
# 2        Denmark                   Western Europe
# 3         Norway                   Western Europe
# 4         Canada                    North America
# ..           ...                              ...
# 153       Rwanda               Sub-Saharan Africa
# 154        Benin               Sub-Saharan Africa
# 155        Syria  Middle East and Northern Africa
# 156      Burundi               Sub-Saharan Africa
# 157         Togo               Sub-Saharan Africa
#
# [158 rows x 2 columns]

# %%
# df.loc[:5, 0:2] # не робит;(
df.loc[:, df.columns[0]: df.columns[3]]
# Out:
#          country                           region  happiness_rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      happiness_score
# 0              7.587
# 1              7.561
# 2              7.527
# 3              7.522
# 4              7.427
# ..               ...
# ...

# %%
df[df.columns[0]].tolist()
# Out:
# ['Switzerland',
#  'Iceland',
#  'Denmark',
#  'Norway',
#  'Canada',
#  'Finland',
#  'Netherlands',
#  'Sweden',
#  'New Zealand',
#  'Australia',
#  'Israel',
#  'Costa Rica',
#  'Austria',
#  'Mexico',
#  'United States',
#  'Brazil',
#  'Luxembourg',
#  'Ireland',
#  'Belgium',
#  'United Arab Emirates',
#  'United Kingdom',
#  'Oman',
#  'Venezuela',
#  'Singapore',
#  'Panama',
#  'Germany',
#  'Chile',
#  'Qatar',
#  'France',
#  'Argentina',
#  'Czech Republic',
#  'Uruguay',
#  'Colombia',
#  'Thailand',
#  'Saudi Arabia',
#  'Spain',
#  'Malta',
#  'Taiwan',
#  'Kuwait',
#  'Suriname',
#  'Trinidad and Tobago',
#  'El Salvador',
#  'Guatemala',
#  'Uzbekistan',
#  'Slovakia',
#  'Japan',
#  'South Korea',
#  'Ecuador',
#  'Bahrain',
#  'Italy',
#  'Bolivia',
#  'Moldova',
#  'Paraguay',
#  'Kazakhstan',
#  'Slovenia',
#  'Lithuania',
#  'Nicaragua',
#  'Peru',
#  'Belarus',
#  'Poland',
#  'Malaysia',
#  'Croatia',
#  'Libya',
#  'Russia',
#  'Jamaica',
#  'North Cyprus',
# ...

# %%
df[DfCols.sum] = df[DfCols.economy__gdp_per_capita] + df[DfCols.happiness_score]
df
# Out:
#          country                           region  happiness_rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      happiness_score  standard_error  economy__gdp_per_capita   family  \
# 0              7.587         0.03411                  1.39651  1.34951
# ...

# %%
df[DfCols.region].unique()
df[DfCols.region].value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: region, dtype: int64

# %%
df[DfCols.happiness_rounded] = round(df[DfCols.happiness_score])
# df.groupby(DfCols.happiness_rounded).count()
df.groupby(DfCols.happiness_rounded).sum()
# Out:
#                    happiness_rank  happiness_score  standard_error  \
# happiness_rounded
# 3.0                           780           15.555         0.27520
# 4.0                          4155          120.462         1.39817
# 5.0                          5140          261.614         2.68030
# 6.0                          1989          232.877         1.98777
# 7.0                           486          188.661         1.06932
# 8.0                            10           30.197         0.15503
#
#                    economy__gdp_per_capita    family  health__life_expectancy  \
# happiness_rounded
# 3.0                                1.39591   2.15827                  1.97806
# 4.0                               13.98158  22.87616                 11.27258
# 5.0                               37.88096  48.90409                 30.29763
# 6.0                               40.64177  44.15136                 29.04703
# ...

# %%
df.plot(x=DfCols.happiness_rank, y=DfCols.health__life_expectancy)
# Out:
# <AxesSubplot: xlabel='happiness_rank'>

# %%
df.plot.hist(x=DfCols.happiness_rank, y=DfCols.health__life_expectancy)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df.plot.scatter(x=DfCols.happiness_rank, y=DfCols.health__life_expectancy)
# Out:
# c:\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1070: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='happiness_rank', ylabel='health__life_expectancy'>

# %%
df.to_csv('NEW_' + file_name)
